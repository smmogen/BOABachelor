# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("Versjon06.csv")
df2 = pd.read_csv("Versjon05.csv") #Med bredde/lengdegrad
df2.head()
# Out:
#         Pris  Boligtype    Eieform bolig  Soverom  Primærrom  Bruksareal  \
# 0  4850000.0   Enebolig  Eier (Selveier)      4.0      206.0       241.0
# 1  2090000.0  Leilighet  Eier (Selveier)      2.0       81.0        81.0
# 2  5490000.0  Leilighet            Andel      3.0      115.0       118.0
# 3  2790000.0   Rekkehus  Eier (Selveier)      4.0      138.0       146.0
# 4  2973000.0        NaN              NaN      NaN       67.0         NaN
#
#    Etasje  Byggeår Energimerking  \
# 0     NaN   1989.0       D - gul
# 1     1.0   2012.0       C - rød
# 2     5.0   2006.0           NaN
# 3     3.0   1984.0   F - oransje
# 4     NaN   2021.0           NaN
#
#                                                  URL  ...  \
# 0  https://www.finn.no/realestate/homes/ad.html?f...  ...
# 1  https://www.finn.no/realestate/homes/ad.html?f...  ...
# 2  https://www.finn.no/realestate/homes/ad.html?f...  ...
# 3  https://www.finn.no/realestate/homes/ad.html?f...  ...
# ...

# %%
plt.scatter(df2['Longitude'],df2['Latitude'], s=2)
